# %%
import interface.processor

# reload the processor module 
# img_dsfaafdsdfdsads
# 
# 
# 
# 
# dfda
# 
# 
# 
# 
# 
# 
# to ensure the latest version is used
import importlib
importlib.reload(interface.processor)
# Out:
# <module 'interface.processor' from 'd:\\local_mydev\\damage_assessment_pipeline\\app\\interface\\processor.py'>

# %%
# params = {
#     'task': 'single_segmentation',
#     'input_file': r"D:\temporal\input\New folder\20_WEEK_5_(_FIELD_A)_md.jpg",
#     'output_dir': r"D:\temporal\input\New folder"
# }

# proc = Processor(params)
# proc.process()

# %%
params = {
    'task': 'single_damage_classification'
    ,'model': 'Regnet'
    ,'input_file': r"D:\temporal\input\20_WEEK_5_(_FIELD_A)_md.jpg"
}

proc = interface.processor.Processor(params)
res = proc.run()

print(res['results'])
# Out:
# ************** MODEL
# Regnet
# \\CATALOGUE.CGIARAD.ORG\AcceleratedBreedingInitiative\1.Data\16. Spidermites_AdrianK\models\onnx\regnet_x_32gf_SpidermitesModel.onnx
# **************
# uint8
# (3000, 4000, 3)
# 0
# 255
# **************
# ************** TO FLOAT
# float32
# (3000, 4000, 3)
# 0.0
# 1.0
# ************** RESIZE
# **************
# float32
# (512, 682, 3)
# 0.0048059397
# 1.0000001
# ************** CENTER CROP
# **************
# float32
# (512, 512, 3)
# 0.0048059397
# 1.0000001
# **************
# ************** NORMALIZE
# float32
# (512, 512, 3)
# 0.0048059397
# 1.0000001
# **************
# **************
# float32
# (3, 512, 512)
# 0.0048059397
# 1.0000001
# **************
# [-0.9596037 -1.1570911  0.7111188  1.0209806]
# {'0-(No damage)': np.float32(-0.9596037), '1-3-(Moderately damaged)': np.float32(-1.1570911), '4-7-(Damaged)': np.float32(0.7111188), '8-10-(Severely damaged)': np.float32(1.0209806), 'filepath': 'D:/temporal/input/20_WEEK_5_(_FIELD_A)_md.jpg', 'basename': '20_WEEK_5_(_FIELD_A)_md.jpg', 'damage': '8-10-(Severely damaged)'}
